# %%
import numpy as np
import pandas as pd
import collections

# %%
data = pd.read_csv('out1.csv')

# %%
data.columns
# Out:
# Index([u'dtg', u'mac', u'rssi', u'ssid', u'oui'], dtype='object')

# %%
mac = data['mac']

# %%
counter = collections.Counter(mac)

# %%
counter
# Out:
# Counter({'04:15:52:4e:7e:a2': 28445, '04:15:52:4e:8a:1e': 23192, '60:67:20:7d:bd:28': 6969, '48:43:7c:75:95:38': 5210, '04:15:52:4c:41:e8': 3587, '84:3a:4b:ca:d9:e0': 3268, '04:15:52:4e:29:1a': 2973, '6c:88:14:3b:93:88': 2781, '5c:51:4f:d6:31:43': 2142, '60:6c:66:1d:d0:71': 1994, '00:26:c6:4a:8d:30': 1705, 'a8:88:08:25:c1:cd': 853, 'e0:9d:31:2d:91:cc': 829, 'a8:86:dd:63:c5:6e': 673, 'cc:08:e0:57:a3:34': 638, '9c:d9:17:18:c4:ec': 636, '48:d7:05:60:21:77': 566, '70:3e:ac:d0:d7:22': 557, '24:77:03:6f:89:c8': 535, '10:41:7f:24:87:17': 422, 'dc:2b:61:ad:7d:89': 390, '18:f6:43:cd:ad:ef': 389, 'a4:4e:31:34:c2:34': 341, 'ec:1f:72:28:56:cf': 336, 'cc:fa:00:b4:aa:6e': 329, '5c:f5:da:2a:e6:47': 329, '84:4b:f5:8a:d6:e5': 283, 'b8:5a:73:c9:f2:82': 268, '7c:4f:b5:9f:b7:1a': 254, 'b4:18:d1:58:49:6b': 253, '84:3a:4b:56:80:fc': 246, 'ec:1f:72:a8:2c:68': 245, '18:67:b0:53:51:10': 237, 'e0:ac:cb:56:df:3c': 228, 'dc:f1:10:3d:ea:04': 201, 'f8:e0:79:68:9c:3c': 198, '5c:f9:38:9e:53:de': 196, 'c4:9a:02:17:c
# ...

# %%
counter_list = list(counter)

# %%
counter_list.index('a8:8e:24:5c:f3:98')
# Out:
# 1447

# %%
whitelist = counter_list[:1446]
print whitelist
# Out:
# ['3a:4e:8d:0f:23:e2', '7c:7a:91:ef:dd:f5', '0c:b3:19:db:d0:a7', '28:5a:eb:dc:3a:1a', '34:4d:f7:64:96:31', 'e2:93:55:d7:34:48', '42:39:90:68:03:b3', 'fc:c2:de:00:70:c1', 'a4:5e:60:bc:55:19', 'cc:c3:ea:d9:dd:39', 'a0:99:9b:3e:46:31', 'a0:99:9b:50:20:66', '10:41:7f:24:87:17', '76:03:6d:b0:1c:be', 'cc:29:f5:5a:35:73', 'a4:e7:31:d8:67:51', '6e:4f:ea:83:6d:c1', '0c:41:3e:91:5f:dc', 'e4:58:e7:20:76:54', 'c0:1a:da:55:b1:c9', '18:f6:43:83:30:c9', 'f0:4f:7c:b0:3e:0b', 'b0:45:19:51:ba:71', '10:2f:6b:d8:71:ab', '3e:38:f6:ab:6e:a6', '80:01:84:5b:03:a4', '90:68:c3:b4:3b:b9', 'e0:c9:7a:26:1a:2e', '72:27:22:50:87:74', 'a4:5e:60:39:15:1a', 'd4:37:d7:9d:6d:36', 'b6:25:f7:36:23:92', '66:b4:a5:91:75:29', '1c:56:fe:28:c8:e6', 'b2:84:b9:c8:73:63', '24:db:ed:7c:23:f6', '00:61:71:cb:1d:db', '18:f6:43:ef:d6:c5', '4c:7c:5f:67:c0:8c', 'fc:19:10:e8:c6:15', 'a8:a6:68:30:b2:bf', 'c0:bd:d1:58:a1:5d', '72:54:63:1e:75:4f', 'aa:8b:db:5f:30:76', 'a0:ec:80:fb:c3:14', '0a:eb:33:2d:29:1b', 'd4:0b:1a:4d:23:61', 'b0:45:19:
# ...

# %%
l = [1,1,2,3,2,2,3,33,3,3,33]
counter1 = collections.Counter(l)
print counter1
# Out:
# Counter({3: 4, 2: 3, 1: 2, 33: 2})

# %%
list(mac).count('70:3e:ac:11:81:c8')
# Out:
# 94

# %%
70:3e:ac:11:81:c8
